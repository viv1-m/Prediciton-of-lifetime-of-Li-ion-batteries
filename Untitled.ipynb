# %%
# %load task.py
import argparse
import datetime
import os

import tensorflow as tf
import keras
from absl import logging

import constants as cst
import data_pipeline as dp
import split_model as split_model
import full_cnn_model as full_cnn_model

# %%
def get_args():
    """Argument parser.

    Returns:
        Dictionary of arguments.
    """
    parser = argparse.ArgumentParser()
    parser.add_argument(
        '--job-dir',
        type=str,
        default=cst.BASE_DIR,
        help='local or GCS location for writing checkpoints and exporting models')
    parser.add_argument(
        '--data-dir-train',
        type=str,
        default=cst.TRAIN_SET,
        help='local or GCS location for reading TFRecord files for the training set')
    parser.add_argument(
        '--data-dir-validate',
        type=str,
        default=cst.TEST_SET,
        help='local or GCS location for reading TFRecord files for the validation set')
    parser.add_argument(
        '--tboard-dir',         # no default so we can construct dynamically with timestamp
        type=str,
        help='local or GCS location for reading TensorBoard files')
    parser.add_argument(
        '--saved-model-dir',    # no default so we can construct dynamically with timestamp
        type=str,
        help='local or GCS location for saving trained Keras models')
    parser.add_argument(
        '--num-epochs',
        type=int,
        default=65,
        help='number of times to go through the data, default=3')
    parser.add_argument(
        '--batch-size',
        default=32,
        type=int,
        help='number of records to read during each training step, default=16')
    parser.add_argument(
        '--window-size',
        default=20,
        type=int,
        help='window size for sliding window in training sample generation, default=100')
    parser.add_argument(
        '--shift',
        default=5,
        type=int,
        help='shift for sliding window in training sample generation, default=20')
    parser.add_argument(
        '--stride',
        default=1,
        type=int,
        help='stride inside sliding window in training sample generation, default=1')
    parser.add_argument(
        '--verbosity',
        choices=['DEBUG', 'ERROR', 'FATAL', 'INFO', 'WARN'],
        default='DEBUG')
    parser.add_argument(
        '--loss',
        default='mean_squared_error',
        type=str,
        help='loss function used by the model, default=mean_squared_error')
    parser.add_argument(
        '--shuffle',
        default=True,
        type=bool,
        help='shuffle the batched dataset, default=True'
    )
    parser.add_argument(
        '--shuffle-buffer',
        default=500,
        type=int,
        help='Bigger buffer size means better shuffling but longer setup time. Default=500'
    )
    parser.add_argument(
        '--save-from',
        default=80,
        type=int,
        help='epoch after which model checkpoints are saved, default=80'
    )
    parser.add_argument(
        '--model',
        default='full_cnn_model',
        type=str,
        help='The type of model to use, default="split_model", options="split_model", "full_cnn_model"'
    )
    args, _ = parser.parse_known_args()
    return args

# %%
def train_and_evaluate(args, tboard_dir, hparams=None):
    """Trains and evaluates the Keras model.

    Uses the Keras model defined in model.py and trains on data loaded and
    preprocessed in data_pipeline.py. Saves the trained model in TensorFlow SavedModel
    format to the path defined in part by the --job-dir argument.

    Args:
    args: dictionary of arguments - see get_args() for details
    """
    # Config datasets for consistent usage
    ds_config = dict(window_size=args.window_size,
                     shift=args.shift,
                     stride=args.stride,
                     batch_size=args.batch_size)
    ds_train_path = args.data_dir_train
    ds_val_path = args.data_dir_validate

    # create model
#     if args.model == 'split_model':
#         print("Using split model!")
#         model = split_model.create_keras_model(window_size=ds_config["window_size"],
#                                                loss=args.loss,
#                                                hparams_config=hparams)
    if args.model == 'full_cnn_model':
        print("Using full cnn model!")
        model = full_cnn_model.create_keras_model(window_size=ds_config["window_size"],
                                                  loss=args.loss,
                                                  hparams_config=hparams)
    
    # Calculate steps_per_epoch_train, steps_per_epoch_test
    # This is needed, since for counting repeat has to be false
    steps_per_epoch_train = calculate_steps_per_epoch(data_dir=ds_train_path, dataset_config=ds_config)
    
    steps_per_epoch_validate = calculate_steps_per_epoch(data_dir=ds_val_path, dataset_config=ds_config)
    
    # load datasets
    dataset_train = dp.create_dataset(data_dir=ds_train_path,
                                      window_size=ds_config["window_size"],
                                      shift=ds_config["shift"],
                                      stride=ds_config["stride"],
                                      batch_size=ds_config["batch_size"])
    
    dataset_validate = dp.create_dataset(data_dir=ds_val_path,
                                         window_size=ds_config["window_size"],
                                         shift=ds_config["shift"],
                                         stride=ds_config["stride"],
                                         batch_size=ds_config["batch_size"])
    
#     # if hparams is passed, we're running a HPO-job
#     if hparams:
#         checkpoint_callback = CustomCheckpoints(save_last_only=True,
#                                                 log_dir=tboard_dir,
#                                                 dataset_path=ds_val_path,
#                                                 dataset_config=ds_config,
#                                                 save_eval_plot=False)
#     else:
#         checkpoint_callback = CustomCheckpoints(save_best_only=True,
#                                                 start_epoch=args.save_from,
#                                                 log_dir=tboard_dir,
#                                                 dataset_path=ds_val_path,
#                                                 dataset_config=ds_config,
#                                                 save_eval_plot=False)
#     callbacks = [
#         tf.keras.callbacks.TensorBoard(log_dir=tboard_dir,
#                                        histogram_freq=0,
#                                        write_graph=False,
#                                        ),
#         checkpoint_callback,
#     ]

    model.summary()
    keras.utils.plot_model(model,'battery_prediction_model.png')
    keras.utils.plot_model(model,'battery_prediction_model_with_shapes.png',show_shapes=True)
    
    # train model
    history = model.fit(
        dataset_train, 
        epochs=args.num_epochs,
        steps_per_epoch=steps_per_epoch_train,
        validation_data=dataset_validate,
        validation_steps=steps_per_epoch_validate,
        verbose=2,
        #callbacks=callbacks
    )
    
    model.save_weights('full_cnn_weights.h5')
    
    mae_current = min(history.history["val_mae_current_cycle"])
    mae_remaining = min(history.history["val_mae_remaining_cycles"])
    return mae_current, mae_remaining

# %%
def calculate_steps_per_epoch(data_dir, dataset_config):
    temp_dataset = dp.create_dataset(data_dir=data_dir,
                                     window_size=dataset_config["window_size"],
                                     shift=dataset_config["shift"],
                                     stride=dataset_config["stride"],
                                     batch_size=dataset_config["batch_size"],
                                     repeat=False)
    steps_per_epoch = 0
    for batch in temp_dataset:
        steps_per_epoch += 1
    return steps_per_epoch


def get_tboard_dir():
    run_timestr = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    if args.tboard_dir is None:
        tboard_dir = os.path.join(cst.TENSORBOARD_DIR, "jobs", run_timestr)
    else:
        tboard_dir = args.tboard_dir
    return tboard_dir

# %%
if __name__ == '__main__':
    args = get_args()
    logging.set_verbosity(args.verbosity)
    train_and_evaluate(args, get_tboard_dir())
# Out:
# Using full cnn model!
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Qdlin (InputLayer)              [(None, 20, 1000, 1) 0
# __________________________________________________________________________________________________
# cnn_detail (Conv2D)             (None, 20, 334, 32)  896         Qdlin[0][0]
# __________________________________________________________________________________________________
# maxpool_detail (MaxPooling2D)   (None, 20, 167, 32)  0           cnn_detail[0][0]
# __________________________________________________________________________________________________
# IR (InputLayer)                 [(None, 20, 1)]      0
# __________________________________________________________________________________________________
# Discharge_time (InputLayer)     [(None, 20, 1)]      0
# __________________________________________________________________________________________________
# QD (InputLayer)                 [(None, 20, 1)]      0
# __________________________________________________________________________________________________
# cnn_detail2 (Conv2D)            (None, 20, 56, 64)   55360       maxpool_detail[0][0]
# __________________________________________________________________________________________________
# concat_scalar (Concatenate)     (None, 20, 3)        0           IR[0][0]
#                                                                  Discharge_time[0][0]
#                                                                  QD[0][0]
# __________________________________________________________________________________________________
# maxpool_detail2 (MaxPooling2D)  (None, 20, 28, 64)   0           cnn_detail2[0][0]
# __________________________________________________________________________________________________
# cnn_scalar (Conv1D)             (None, 20, 32)       320         concat_scalar[0][0]
# __________________________________________________________________________________________________
# cnn_detail3 (Conv2D)            (None, 20, 10, 128)  221312      maxpool_detail2[0][0]
# __________________________________________________________________________________________________
# cnn_scalar2 (Conv1D)            (None, 20, 64)       6208        cnn_scalar[0][0]
# __________________________________________________________________________________________________
# maxpool_detail3 (MaxPooling2D)  (None, 10, 5, 128)   0           cnn_detail3[0][0]
# __________________________________________________________________________________________________
# maxpool_scalar (MaxPooling1D)   (None, 10, 64)       0           cnn_scalar2[0][0]
# __________________________________________________________________________________________________
# flat_detail (Flatten)           (None, 6400)         0           maxpool_detail3[0][0]
# __________________________________________________________________________________________________
# flat_scalar (Flatten)           (None, 640)          0           maxpool_scalar[0][0]
# __________________________________________________________________________________________________
# dropout_detail (Dropout)        (None, 6400)         0           flat_detail[0][0]
# __________________________________________________________________________________________________
# dropout_scalar (Dropout)        (None, 640)          0           flat_scalar[0][0]
# __________________________________________________________________________________________________
# concat_all (Concatenate)        (None, 7040)         0           dropout_detail[0][0]
#                                                                  dropout_scalar[0][0]
# __________________________________________________________________________________________________
# hidden_dense2 (Dense)           (None, 32)           225312      concat_all[0][0]
# __________________________________________________________________________________________________
# dropout_output (Dropout)        (None, 32)           0           hidden_dense2[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 2)            66          dropout_output[0][0]
# ==================================================================================================
# Total params: 509,474
# Trainable params: 509,474
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/65
# 168/168 - 70s - loss: 0.0280 - mae_current_cycle: 272.1909 - mae_remaining_cycles: 245.2870 - val_loss: 0.0389 - val_mae_current_cycle: 293.3588 - val_mae_remaining_cycles: 268.6330
# Epoch 2/65
# 168/168 - 72s - loss: 0.0244 - mae_current_cycle: 261.1230 - mae_remaining_cycles: 213.8422 - val_loss: 0.0340 - val_mae_current_cycle: 277.5705 - val_mae_remaining_cycles: 198.4912
# Epoch 3/65
# 168/168 - 72s - loss: 0.0226 - mae_current_cycle: 254.8724 - mae_remaining_cycles: 185.8810 - val_loss: 0.0289 - val_mae_current_cycle: 266.1594 - val_mae_remaining_cycles: 181.7306
# Epoch 4/65
# 168/168 - 72s - loss: 0.0211 - mae_current_cycle: 250.1866 - mae_remaining_cycles: 175.6313 - val_loss: 0.0323 - val_mae_current_cycle: 262.2989 - val_mae_remaining_cycles: 214.3637
# Epoch 5/65
# 168/168 - 72s - loss: 0.0209 - mae_current_cycle: 241.5097 - mae_remaining_cycles: 178.4883 - val_loss: 0.0295 - val_mae_current_cycle: 257.6934 - val_mae_remaining_cycles: 192.0438
# Epoch 6/65
# 168/168 - 71s - loss: 0.0204 - mae_current_cycle: 240.7265 - mae_remaining_cycles: 172.0348 - val_loss: 0.0300 - val_mae_current_cycle: 255.6039 - val_mae_remaining_cycles: 187.0653
# Epoch 7/65
# 168/168 - 72s - loss: 0.0188 - mae_current_cycle: 236.4964 - mae_remaining_cycles: 168.0909 - val_loss: 0.0232 - val_mae_current_cycle: 284.4369 - val_mae_remaining_cycles: 187.4393
# Epoch 8/65
# 168/168 - 74s - loss: 0.0196 - mae_current_cycle: 233.9706 - mae_remaining_cycles: 169.4031 - val_loss: 0.0254 - val_mae_current_cycle: 254.2235 - val_mae_remaining_cycles: 170.6824
# Epoch 9/65
# 168/168 - 73s - loss: 0.0191 - mae_current_cycle: 233.1649 - mae_remaining_cycles: 162.8393 - val_loss: 0.0234 - val_mae_current_cycle: 265.4554 - val_mae_remaining_cycles: 167.2091
# Epoch 10/65
# 168/168 - 71s - loss: 0.0161 - mae_current_cycle: 208.8079 - mae_remaining_cycles: 161.5656 - val_loss: 0.0303 - val_mae_current_cycle: 397.8363 - val_mae_remaining_cycles: 209.0458
# Epoch 11/65
# 168/168 - 71s - loss: 0.0186 - mae_current_cycle: 230.3641 - mae_remaining_cycles: 166.5786 - val_loss: 0.0307 - val_mae_current_cycle: 247.3282 - val_mae_remaining_cycles: 200.6745
# Epoch 12/65
# 168/168 - 71s - loss: 0.0185 - mae_current_cycle: 228.4358 - mae_remaining_cycles: 164.8437 - val_loss: 0.0229 - val_mae_current_cycle: 248.3123 - val_mae_remaining_cycles: 170.8225
# Epoch 13/65
# 168/168 - 71s - loss: 0.0171 - mae_current_cycle: 214.3307 - mae_remaining_cycles: 163.0261 - val_loss: 0.0224 - val_mae_current_cycle: 244.4672 - val_mae_remaining_cycles: 167.2527
# Epoch 14/65
# 168/168 - 73s - loss: 0.0183 - mae_current_cycle: 221.8753 - mae_remaining_cycles: 163.7184 - val_loss: 0.0253 - val_mae_current_cycle: 238.0031 - val_mae_remaining_cycles: 178.9871
# Epoch 15/65
# 168/168 - 100s - loss: 0.0162 - mae_current_cycle: 207.6642 - mae_remaining_cycles: 154.1881 - val_loss: 0.0353 - val_mae_current_cycle: 411.1852 - val_mae_remaining_cycles: 280.5443
# Epoch 16/65
# 168/168 - 80s - loss: 0.0184 - mae_current_cycle: 223.1270 - mae_remaining_cycles: 163.4895 - val_loss: 0.0263 - val_mae_current_cycle: 241.5422 - val_mae_remaining_cycles: 170.9604
# Epoch 17/65
# 168/168 - 78s - loss: 0.0165 - mae_current_cycle: 201.6378 - mae_remaining_cycles: 160.2114 - val_loss: 0.0234 - val_mae_current_cycle: 297.7480 - val_mae_remaining_cycles: 167.7663
# Epoch 18/65
# 168/168 - 85s - loss: 0.0181 - mae_current_cycle: 225.5189 - mae_remaining_cycles: 163.6878 - val_loss: 0.0239 - val_mae_current_cycle: 235.0914 - val_mae_remaining_cycles: 180.3689
# Epoch 19/65
# 168/168 - 84s - loss: 0.0143 - mae_current_cycle: 200.9567 - mae_remaining_cycles: 149.7967 - val_loss: 0.0298 - val_mae_current_cycle: 339.2045 - val_mae_remaining_cycles: 279.2586
# Epoch 20/65
# 168/168 - 73s - loss: 0.0179 - mae_current_cycle: 215.0141 - mae_remaining_cycles: 171.2142 - val_loss: 0.0217 - val_mae_current_cycle: 231.4193 - val_mae_remaining_cycles: 171.7298
# Epoch 21/65
# 168/168 - 71s - loss: 0.0162 - mae_current_cycle: 208.7511 - mae_remaining_cycles: 158.4373 - val_loss: 0.0267 - val_mae_current_cycle: 233.9173 - val_mae_remaining_cycles: 180.3619
# Epoch 22/65
# 168/168 - 71s - loss: 0.0157 - mae_current_cycle: 202.7220 - mae_remaining_cycles: 155.7297 - val_loss: 0.0214 - val_mae_current_cycle: 229.9558 - val_mae_remaining_cycles: 171.2450
# Epoch 23/65
# 168/168 - 72s - loss: 0.0147 - mae_current_cycle: 197.6298 - mae_remaining_cycles: 153.6773 - val_loss: 0.0229 - val_mae_current_cycle: 218.8053 - val_mae_remaining_cycles: 174.8022
# Epoch 24/65
# 168/168 - 72s - loss: 0.0142 - mae_current_cycle: 188.3028 - mae_remaining_cycles: 149.0464 - val_loss: 0.0354 - val_mae_current_cycle: 331.0450 - val_mae_remaining_cycles: 361.7678
# Epoch 25/65
# 168/168 - 71s - loss: 0.0180 - mae_current_cycle: 219.4725 - mae_remaining_cycles: 160.5204 - val_loss: 0.0261 - val_mae_current_cycle: 231.3284 - val_mae_remaining_cycles: 185.0843
# Epoch 26/65
# 168/168 - 72s - loss: 0.0146 - mae_current_cycle: 190.5321 - mae_remaining_cycles: 153.4255 - val_loss: 0.0206 - val_mae_current_cycle: 278.9424 - val_mae_remaining_cycles: 176.6209
# Epoch 27/65
# 168/168 - 71s - loss: 0.0139 - mae_current_cycle: 192.4942 - mae_remaining_cycles: 147.3222 - val_loss: 0.0301 - val_mae_current_cycle: 245.3911 - val_mae_remaining_cycles: 191.6651
# Epoch 28/65
# 168/168 - 72s - loss: 0.0145 - mae_current_cycle: 191.4379 - mae_remaining_cycles: 148.0142 - val_loss: 0.0215 - val_mae_current_cycle: 218.3768 - val_mae_remaining_cycles: 165.7380
# Epoch 29/65
# 168/168 - 87s - loss: 0.0141 - mae_current_cycle: 188.3624 - mae_remaining_cycles: 151.0405 - val_loss: 0.0228 - val_mae_current_cycle: 211.4153 - val_mae_remaining_cycles: 177.2335
# Epoch 30/65
# 168/168 - 83s - loss: 0.0139 - mae_current_cycle: 187.7297 - mae_remaining_cycles: 146.7620 - val_loss: 0.0239 - val_mae_current_cycle: 209.0321 - val_mae_remaining_cycles: 192.9565
# Epoch 31/65
# 168/168 - 80s - loss: 0.0138 - mae_current_cycle: 183.3316 - mae_remaining_cycles: 147.9849 - val_loss: 0.0196 - val_mae_current_cycle: 238.2261 - val_mae_remaining_cycles: 217.9849
# Epoch 32/65
# 168/168 - 79s - loss: 0.0155 - mae_current_cycle: 205.1819 - mae_remaining_cycles: 152.2171 - val_loss: 0.0232 - val_mae_current_cycle: 219.2720 - val_mae_remaining_cycles: 174.2240
# Epoch 33/65
# 168/168 - 101s - loss: 0.0133 - mae_current_cycle: 184.5862 - mae_remaining_cycles: 145.2725 - val_loss: 0.0220 - val_mae_current_cycle: 201.7954 - val_mae_remaining_cycles: 189.6758
# Epoch 34/65
# 168/168 - 106s - loss: 0.0135 - mae_current_cycle: 183.2281 - mae_remaining_cycles: 145.0903 - val_loss: 0.0193 - val_mae_current_cycle: 233.2514 - val_mae_remaining_cycles: 222.1947
# Epoch 35/65
# 168/168 - 80s - loss: 0.0140 - mae_current_cycle: 192.9909 - mae_remaining_cycles: 150.8098 - val_loss: 0.0196 - val_mae_current_cycle: 204.7719 - val_mae_remaining_cycles: 166.1884
# Epoch 36/65
# 168/168 - 115s - loss: 0.0135 - mae_current_cycle: 185.4128 - mae_remaining_cycles: 149.3486 - val_loss: 0.0192 - val_mae_current_cycle: 205.4397 - val_mae_remaining_cycles: 167.7507
# Epoch 37/65
# 168/168 - 84s - loss: 0.0119 - mae_current_cycle: 170.6610 - mae_remaining_cycles: 142.4855 - val_loss: 0.0272 - val_mae_current_cycle: 258.9780 - val_mae_remaining_cycles: 309.8618
# Epoch 38/65
# 168/168 - 79s - loss: 0.0154 - mae_current_cycle: 198.0506 - mae_remaining_cycles: 162.4243 - val_loss: 0.0167 - val_mae_current_cycle: 213.8983 - val_mae_remaining_cycles: 182.8046
# Epoch 39/65
# 168/168 - 77s - loss: 0.0130 - mae_current_cycle: 182.0412 - mae_remaining_cycles: 153.9211 - val_loss: 0.0169 - val_mae_current_cycle: 201.0182 - val_mae_remaining_cycles: 161.4783
# Epoch 40/65
# 168/168 - 78s - loss: 0.0126 - mae_current_cycle: 178.4629 - mae_remaining_cycles: 145.5829 - val_loss: 0.0184 - val_mae_current_cycle: 197.7302 - val_mae_remaining_cycles: 162.9998
# Epoch 41/65
# 168/168 - 82s - loss: 0.0123 - mae_current_cycle: 172.9843 - mae_remaining_cycles: 146.6244 - val_loss: 0.0198 - val_mae_current_cycle: 228.8795 - val_mae_remaining_cycles: 225.7142
# Epoch 42/65
# 168/168 - 78s - loss: 0.0128 - mae_current_cycle: 186.5228 - mae_remaining_cycles: 144.8998 - val_loss: 0.0259 - val_mae_current_cycle: 245.5810 - val_mae_remaining_cycles: 300.1421
# Epoch 43/65
# 168/168 - 77s - loss: 0.0134 - mae_current_cycle: 186.9648 - mae_remaining_cycles: 157.5453 - val_loss: 0.0187 - val_mae_current_cycle: 235.2708 - val_mae_remaining_cycles: 185.3373
# Epoch 44/65
# 168/168 - 74s - loss: 0.0116 - mae_current_cycle: 170.8283 - mae_remaining_cycles: 138.3788 - val_loss: 0.0200 - val_mae_current_cycle: 262.9476 - val_mae_remaining_cycles: 193.4248
# Epoch 45/65
# 168/168 - 74s - loss: 0.0148 - mae_current_cycle: 190.6331 - mae_remaining_cycles: 153.7586 - val_loss: 0.0179 - val_mae_current_cycle: 200.0059 - val_mae_remaining_cycles: 165.3167
# Epoch 46/65
# 168/168 - 76s - loss: 0.0128 - mae_current_cycle: 183.3673 - mae_remaining_cycles: 149.4282 - val_loss: 0.0181 - val_mae_current_cycle: 201.7047 - val_mae_remaining_cycles: 164.8526
# Epoch 47/65
# 168/168 - 76s - loss: 0.0118 - mae_current_cycle: 169.3296 - mae_remaining_cycles: 146.1496 - val_loss: 0.0181 - val_mae_current_cycle: 187.7268 - val_mae_remaining_cycles: 166.9880
# Epoch 48/65
# 168/168 - 72s - loss: 0.0122 - mae_current_cycle: 174.4492 - mae_remaining_cycles: 143.2064 - val_loss: 0.0151 - val_mae_current_cycle: 185.6224 - val_mae_remaining_cycles: 158.2529
# Epoch 49/65
# 168/168 - 72s - loss: 0.0125 - mae_current_cycle: 174.7717 - mae_remaining_cycles: 149.6465 - val_loss: 0.0181 - val_mae_current_cycle: 199.1372 - val_mae_remaining_cycles: 165.4286
# Epoch 50/65
# 168/168 - 73s - loss: 0.0108 - mae_current_cycle: 165.8501 - mae_remaining_cycles: 133.9379 - val_loss: 0.0257 - val_mae_current_cycle: 252.9110 - val_mae_remaining_cycles: 276.5572
# Epoch 51/65
# 168/168 - 72s - loss: 0.0148 - mae_current_cycle: 191.3110 - mae_remaining_cycles: 159.4163 - val_loss: 0.0164 - val_mae_current_cycle: 189.1741 - val_mae_remaining_cycles: 161.3739
# Epoch 52/65
# 168/168 - 73s - loss: 0.0122 - mae_current_cycle: 170.6374 - mae_remaining_cycles: 148.8251 - val_loss: 0.0177 - val_mae_current_cycle: 186.8898 - val_mae_remaining_cycles: 164.1327
# Epoch 53/65
# 168/168 - 74s - loss: 0.0115 - mae_current_cycle: 165.9745 - mae_remaining_cycles: 143.6478 - val_loss: 0.0161 - val_mae_current_cycle: 177.3369 - val_mae_remaining_cycles: 159.9397
# Epoch 54/65
# 168/168 - 75s - loss: 0.0113 - mae_current_cycle: 160.8988 - mae_remaining_cycles: 145.0114 - val_loss: 0.0181 - val_mae_current_cycle: 185.2845 - val_mae_remaining_cycles: 167.5952
# Epoch 55/65
# 168/168 - 71s - loss: 0.0114 - mae_current_cycle: 166.4191 - mae_remaining_cycles: 143.5375 - val_loss: 0.0209 - val_mae_current_cycle: 194.5177 - val_mae_remaining_cycles: 177.8448
# Epoch 56/65
# 168/168 - 71s - loss: 0.0112 - mae_current_cycle: 162.7572 - mae_remaining_cycles: 145.2391 - val_loss: 0.0178 - val_mae_current_cycle: 171.2048 - val_mae_remaining_cycles: 171.0504
# Epoch 57/65
# 168/168 - 71s - loss: 0.0114 - mae_current_cycle: 166.5021 - mae_remaining_cycles: 141.5380 - val_loss: 0.0178 - val_mae_current_cycle: 182.3178 - val_mae_remaining_cycles: 165.8206
# Epoch 58/65
# 168/168 - 71s - loss: 0.0096 - mae_current_cycle: 156.1646 - mae_remaining_cycles: 128.3783 - val_loss: 0.0210 - val_mae_current_cycle: 194.9715 - val_mae_remaining_cycles: 261.3566
# Epoch 59/65
# 168/168 - 71s - loss: 0.0108 - mae_current_cycle: 156.5204 - mae_remaining_cycles: 146.1794 - val_loss: 0.0156 - val_mae_current_cycle: 171.4891 - val_mae_remaining_cycles: 216.3653
# Epoch 60/65
# 168/168 - 71s - loss: 0.0114 - mae_current_cycle: 163.2879 - mae_remaining_cycles: 145.1132 - val_loss: 0.0174 - val_mae_current_cycle: 174.2124 - val_mae_remaining_cycles: 169.1786
# Epoch 61/65
# 168/168 - 71s - loss: 0.0100 - mae_current_cycle: 150.1725 - mae_remaining_cycles: 137.3554 - val_loss: 0.0204 - val_mae_current_cycle: 228.1149 - val_mae_remaining_cycles: 171.8617
# Epoch 62/65
# 168/168 - 71s - loss: 0.0107 - mae_current_cycle: 156.5682 - mae_remaining_cycles: 142.5524 - val_loss: 0.0166 - val_mae_current_cycle: 165.7241 - val_mae_remaining_cycles: 164.6405
# Epoch 63/65
# 168/168 - 71s - loss: 0.0109 - mae_current_cycle: 153.1146 - mae_remaining_cycles: 146.2809 - val_loss: 0.0167 - val_mae_current_cycle: 193.6238 - val_mae_remaining_cycles: 162.0827
# Epoch 64/65
# 168/168 - 72s - loss: 0.0119 - mae_current_cycle: 161.9301 - mae_remaining_cycles: 149.4326 - val_loss: 0.0155 - val_mae_current_cycle: 168.8754 - val_mae_remaining_cycles: 160.0663
# Epoch 65/65
# 168/168 - 71s - loss: 0.0099 - mae_current_cycle: 148.9836 - mae_remaining_cycles: 137.4657 - val_loss: 0.0135 - val_mae_current_cycle: 161.5102 - val_mae_remaining_cycles: 171.2265

# %%
model = full_cnn_model.create_keras_model(args.window_size,
                                                  loss=args.loss,
                                                  hparams_config=None)

# %%
model.load_weights('full_cnn_weights.h5')

# %%
model.summary()
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Qdlin (InputLayer)              [(None, 20, 1000, 1) 0
# __________________________________________________________________________________________________
# cnn_detail (Conv2D)             (None, 20, 334, 32)  896         Qdlin[0][0]
# __________________________________________________________________________________________________
# maxpool_detail (MaxPooling2D)   (None, 20, 167, 32)  0           cnn_detail[0][0]
# __________________________________________________________________________________________________
# IR (InputLayer)                 [(None, 20, 1)]      0
# __________________________________________________________________________________________________
# Discharge_time (InputLayer)     [(None, 20, 1)]      0
# __________________________________________________________________________________________________
# QD (InputLayer)                 [(None, 20, 1)]      0
# __________________________________________________________________________________________________
# cnn_detail2 (Conv2D)            (None, 20, 56, 64)   55360       maxpool_detail[0][0]
# __________________________________________________________________________________________________
# concat_scalar (Concatenate)     (None, 20, 3)        0           IR[0][0]
#                                                                  Discharge_time[0][0]
#                                                                  QD[0][0]
# __________________________________________________________________________________________________
# maxpool_detail2 (MaxPooling2D)  (None, 20, 28, 64)   0           cnn_detail2[0][0]
# __________________________________________________________________________________________________
# cnn_scalar (Conv1D)             (None, 20, 32)       320         concat_scalar[0][0]
# __________________________________________________________________________________________________
# cnn_detail3 (Conv2D)            (None, 20, 10, 128)  221312      maxpool_detail2[0][0]
# __________________________________________________________________________________________________
# cnn_scalar2 (Conv1D)            (None, 20, 64)       6208        cnn_scalar[0][0]
# __________________________________________________________________________________________________
# maxpool_detail3 (MaxPooling2D)  (None, 10, 5, 128)   0           cnn_detail3[0][0]
# __________________________________________________________________________________________________
# maxpool_scalar (MaxPooling1D)   (None, 10, 64)       0           cnn_scalar2[0][0]
# __________________________________________________________________________________________________
# flat_detail (Flatten)           (None, 6400)         0           maxpool_detail3[0][0]
# __________________________________________________________________________________________________
# flat_scalar (Flatten)           (None, 640)          0           maxpool_scalar[0][0]
# __________________________________________________________________________________________________
# dropout_detail (Dropout)        (None, 6400)         0           flat_detail[0][0]
# __________________________________________________________________________________________________
# dropout_scalar (Dropout)        (None, 640)          0           flat_scalar[0][0]
# __________________________________________________________________________________________________
# concat_all (Concatenate)        (None, 7040)         0           dropout_detail[0][0]
#                                                                  dropout_scalar[0][0]
# __________________________________________________________________________________________________
# hidden_dense2 (Dense)           (None, 32)           225312      concat_all[0][0]
# __________________________________________________________________________________________________
# dropout_output (Dropout)        (None, 32)           0           hidden_dense2[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 2)            66          dropout_output[0][0]
# ==================================================================================================
# Total params: 509,474
# Trainable params: 509,474
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
args = get_args()

# %%
ds_config = dict(window_size=args.window_size,
                     shift=args.shift,
                     stride=args.stride,
                     batch_size=args.batch_size)

# %%
dataset_test = dp.create_dataset(data_dir=cst.TEST_SET,
                                      window_size=ds_config["window_size"],
                                      shift=ds_config["shift"],
                                      stride=ds_config["stride"],
                                      batch_size=ds_config["batch_size"],
                                      repeat = None)

# %%
model.evaluate(dataset_test)
# Out:
# 186/186 [==============================] - 16s 87ms/step - loss: 0.0135 - mae_current_cycle: 161.4750 - mae_remaining_cycles: 171.1585
# [0.013499243184924126, 161.47503662109375, 171.15847778320312]
